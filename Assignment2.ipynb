# %%
#dictionary
bio_data = {
    'Name':'santhoshini',
    'Age' :29,
    'phone_number':'9750472963',
    'country':'singapore',
    'level':'N5'
}
print("Bio Data")
for key,value in bio_data.items():
  print(f"{key}:{value}")
# Out:
# Bio Data
# Name:santhoshini
# Age:29
# phone_number:9750472963
# country:singapore
# level:N5
